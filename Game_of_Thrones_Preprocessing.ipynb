# %%
import pandas as pd 
import os 
os.chdir(r'C:\Users\aleen\Desktop\Data Science\Text Analytics\Exam Project\Data\IMDB')

# %%
e1 = pd.read_csv('Episode1', index_col=[0])
e1.drop_duplicates(inplace=True)
e1.shape
# Out:
# (652, 3)

# %%
e2 = pd.read_csv('Episode2', index_col=[0])
e2.drop_duplicates(inplace=True)
e2.shape
# Out:
# (538, 3)

# %%
e3 = pd.read_csv('Episode3', index_col=[0])
e3.drop_duplicates(inplace=True)
e3.shape
# Out:
# (3707, 3)

# %%
e4 = pd.read_csv('Episode4', index_col=[0])
e4.drop_duplicates(inplace=True)
e4.shape
# Out:
# (2295, 3)

# %%
e5 = pd.read_csv('Episode5', index_col=[0])
e5.drop_duplicates(inplace=True)
e5.shape
# Out:
# (3884, 3)

# %%
e6 = pd.read_csv('Episode6', index_col=[0])
e6.drop_duplicates(inplace=True)
e6.shape
# Out:
# (6851, 3)

# %%
e1.head()
# Out:
#    review_rating                                        review_text  \
# 0            8.0  Opening credits! The change in the credits has...
# 1            7.0                                                NaN
# 2            7.0  Its not bad, it is just becoming very blank, w...
# 3            5.0                                                NaN
# 4            7.0  This was a rather slow episode, more of a buil...
#
#                                  review_title
# 0                               We warmed up!
# 1   Underwhelming, bordering on disappointing
# 2     You can tell they have run out of books
# 3        An extension of the tone of Season 7
# 4                         I like GOT, but....

# %%
frame = [e1,e2,e3,e4,e5,e6]

# %%
for e in frame:
    print(e.review_rating.value_counts(normalize=True))
# Out:
# 10.0    0.342229
# 9.0     0.155416
# 1.0     0.092622
# 8.0     0.092622
# 6.0     0.091052
# 7.0     0.080063
# 5.0     0.056515
# 4.0     0.040816
# 3.0     0.029827
# 2.0     0.018838
# Name: review_rating, dtype: float64
# 10.0    0.465779
# 9.0     0.123574
# 1.0     0.096958
# 7.0     0.060837
# 6.0     0.057034
# 8.0     0.057034
# 5.0     0.055133
# 4.0     0.032319
# 2.0     0.028517
# 3.0     0.022814
# Name: review_rating, dtype: float64
# 10.0    0.324235
# 1.0     0.256410
# 3.0     0.065619
# 2.0     0.060105
# 5.0     0.056796
# 9.0     0.052661
# 6.0     0.052109
# 4.0     0.050455
# 7.0     0.046044
# 8.0     0.035567
# Name: review_rating, dtype: float64
# 1.0     0.346188
# 10.0    0.166816
# 2.0     0.084305
# 3.0     0.075336
# 5.0     0.074888
# 8.0     0.060987
# 4.0     0.057399
# 9.0     0.056502
# 6.0     0.039013
# 7.0     0.038565
# Name: review_rating, dtype: float64
# 10.0    0.318898
# 1.0     0.279003
# 9.0     0.067454
# 2.0     0.065354
# ...

# %%
for e in frame:
    print(e.isna().sum())
# Out:
# review_rating    15
# review_text      29
# review_title      0
# dtype: int64
# review_rating    12
# review_text      25
# review_title      0
# dtype: int64
# review_rating     80
# review_text      105
# review_title       0
# dtype: int64
# review_rating    65
# review_text      90
# review_title      0
# dtype: int64
# review_rating     74
# review_text      103
# review_title       0
# dtype: int64
# review_rating    123
# review_text      207
# review_title       0
# dtype: int64

# %%
for e in frame: 
    e.dropna(inplace = True)

# %%
for e in frame:
    print(e.isna().sum())
# Out:
# review_rating    0
# review_text      0
# review_title     0
# dtype: int64
# review_rating    0
# review_text      0
# review_title     0
# dtype: int64
# review_rating    0
# review_text      0
# review_title     0
# dtype: int64
# review_rating    0
# review_text      0
# review_title     0
# dtype: int64
# review_rating    0
# review_text      0
# review_title     0
# dtype: int64
# review_rating    0
# review_text      0
# review_title     0
# dtype: int64

# %%
frame_copy = frame
for e in frame:
    e.drop(e[ (e.review_rating == 5) | (e.review_rating == 6)].index, axis=0, inplace=True)

# %%
for e in frame:
    print(e.review_rating.value_counts(normalize=True))
# Out:
# 10.0    0.404990
# 9.0     0.186180
# 8.0     0.109405
# 1.0     0.107486
# 7.0     0.092131
# 4.0     0.042226
# 3.0     0.036468
# 2.0     0.021113
# Name: review_rating, dtype: float64
# 10.0    0.529018
# 9.0     0.133929
# 1.0     0.109375
# 7.0     0.069196
# 8.0     0.066964
# 4.0     0.035714
# 2.0     0.033482
# 3.0     0.022321
# Name: review_rating, dtype: float64
# 10.0    0.364706
# 1.0     0.290302
# 3.0     0.073768
# 2.0     0.066773
# 9.0     0.058506
# 4.0     0.055008
# 7.0     0.051510
# 8.0     0.039428
# Name: review_rating, dtype: float64
# 1.0     0.395263
# 10.0    0.189474
# 2.0     0.092632
# 3.0     0.085263
# 8.0     0.067895
# 4.0     0.064211
# 9.0     0.061579
# 7.0     0.043684
# Name: review_rating, dtype: float64
# 10.0    0.349809
# 1.0     0.306561
# 9.0     0.073845
# 2.0     0.071786
# 3.0     0.061489
# 8.0     0.053545
# 4.0     0.044131
# 7.0     0.038835
# Name: review_rating, dtype: float64
# 1.0     0.62544
# 10.0    0.13120
# ...

# %%
for e in frame: 
    print(e.shape)
# Out:
# (521, 3)
# (448, 3)
# (3145, 3)
# (1900, 3)
# (3399, 3)
# (6250, 3)

# %%
for e in frame:
    e['review_rating'] = e['review_rating'].map({1: 0, 2: 0, 3:0, 4:0, 7:1, 8:1, 9:1, 10:1})

# %%
for e in frame:
    print(e.review_rating.value_counts(normalize=True))
# Out:
# 1    0.792706
# 0    0.207294
# Name: review_rating, dtype: float64
# 1    0.799107
# 0    0.200893
# Name: review_rating, dtype: float64
# 1    0.514149
# 0    0.485851
# Name: review_rating, dtype: float64
# 0    0.637368
# 1    0.362632
# Name: review_rating, dtype: float64
# 1    0.516034
# 0    0.483966
# Name: review_rating, dtype: float64
# 0    0.77648
# 1    0.22352
# Name: review_rating, dtype: float64

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from bs4 import BeautifulSoup
import spacy
import re,string,unicodedata
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.stem import LancasterStemmer,WordNetLemmatizer
from textblob import TextBlob
from sklearn.metrics import accuracy_score
import re
import warnings
import os
warnings.filterwarnings('ignore')

# %%
tokenizer=ToktokTokenizer()
stopword_list=nltk.corpus.stopwords.words('english')

def wordcloud(dataframe):
    wordcloud = WordCloud(width=1600, height=800, max_font_size=200, background_color="black",stopwords=stopword_list).generate(" ".join([str(i) for i in dataframe]))
    plt.figure(figsize = (12,10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
    
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)

def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    return text

def remove_accented_characters(text):
    text=unicodedata.normalize('NFKD',text).encode('ascii','ignore').decode('utf-8','ignore')
    return text

def remove_special_characters(text, remove_digits=True):
    if remove_digits == False:
        pattern = r'[^a-zA-z0-9\s]'
    else: pattern = r'[^a-zA-z\s]'
    text  = re.sub(pattern,'',text)
    return text

def simple_stemmer(text):
    ps=nltk.porter.PorterStemmer()
    text= ' '.join([ps.stem(word) for word in text.split()])
    return text

def remove_stopwords(text, is_lower_case=False):
    stop=set(stopwords.words('english'))
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

def lowercase(text):
    text = text.lower()
    return text
    
def tokenize_text(text):
    text = tokenizer(text)
    text = text.lower()
    return text

from nltk.stem import WordNetLemmatizer

def lemmatize_text(text):
    lemma = WorntLemmatizer()
    text = ' '.join([lemma.stem(word) for word in text.split()])
    return text

# %%
wordcloud(e1.review_text)

# %%
wordcloud(e2.review_text)

# %%
wordcloud(e3.review_text)

# %%
wordcloud(e4.review_text)

# %%
wordcloud(e5.review_text)

# %%
wordcloud(e6.review_text)

# %%
for df in frame:
    df['review_text'] = df['review_text'].apply(denoise_text)
    df['review_text'] = df['review_text'].apply(remove_accented_characters)
    df['review_text'] = df['review_text'].apply(remove_special_characters)
    df['review_text'] = df['review_text'].apply(remove_stopwords)
    df['review_text'] = df['review_text'].apply(simple_stemmer)
    df['review_text'] = df['review_text'].apply(lowercase)

# %%
e6.head()
# Out:
#    review_rating                                        review_text  \
# 0              0                      incompet reward blind loyalti
# 1              0  dear dan davei long huge fan avid support game...
# 2              0  good thing music better everwork behind camera...
# 3              0  oh like high school drama class given access g...
# 4              0  forget subplot forget mysteri around white wal...
#
#                                         review_title
# 0                                   Varys once said,
# 1                          A Message to Dan and Dave
# 2                            This show became a Meme
# 3   Better if Whitewalkers had won and last episo...
# 4                      This is utterly disrespectful

# %%
df = pd.concat(frame)

# %%
df.shape
# Out:
# (15663, 3)

# %%
df.isna().sum()
# Out:
# review_rating    0
# review_text      0
# review_title     0
# dtype: int64

# %%
df.to_csv('GOT')

# %%
reviews = df['review_text']
sentiments = df['review_rating']

print(reviews.shape, sentiments.shape)
# Out:
# (15663,) (15663,)

# %%
cv = CountVectorizer(min_df=0,max_df=1,binary=False,ngram_range=(1,3))
cv_reviews = cv.fit_transform(reviews)
cv_reviews = cv.transform(reviews)

print('BOW shape:',cv_reviews.shape)
# Out:
# BOW shape: (15663, 807068)

# %%
#list(cv.get_feature_names())
# Out:
# ['______',
#  '______ person',
#  '______ person script',
#  '_____________________',
#  '_____________________ sansa',
#  '_____________________ sansa think',
#  '______________________________________________________so',
#  '______________________________________________________so like',
#  '______________________________________________________so like event',
#  '_almost_',
#  '_almost_ kill',
#  '_almost_ kill time',
#  '_i_',
#  '_real_almost',
#  '_real_almost everyon',
#  '_real_almost everyon seem',
#  'aa propheci',
#  'aa propheci mayb',
#  'aa sinc',
#  'aa sinc book',
#  'aaa',
#  'aaa great',
#  'aaa great stori',
#  'aaaaaaaagh',
#  'aaaaaaaagh one',
#  'aaaaaaaagh one blame',
#  'aaaaaaaahhh',
#  'aaaaaah',
#  'aaaaaah im',
#  'aaaaaah im sad',
#  'aaaaaannnnndddd',
#  'aaaaaannnnndddd gone',
#  'aaaaaannnnndddd gone need',
#  'aaaaand come',
#  'aaaaand come almighti',
#  'aaaaand that',
#  'aaaaand that itshort',
#  'aaaahhh',
#  'aaaahhh charact',
# ...

# %%
tv=TfidfVectorizer(min_df=0.0,max_df=1.0,use_idf=True,ngram_range=(1,3),sublinear_tf=True)
tv_reviews=tv.fit_transform(reviews)
tv_reviews=tv.transform(reviews)

print('Tfidf shape:',tv_reviews.shape)
# Out:
# Tfidf shape: (15663, 141)

# %%
tv=TfidfVectorizer(min_df=0.05,max_df=0.9,use_idf=True,ngram_range=(1,3),sublinear_tf=True)
tv_reviews=tv.fit_transform(cv)

print('Tfidf shape:',tv_reviews.shape)

# %%
reviews
# Out:
# 0       open credit chang credit nice radic chang icon...
# 2       bad becom blank made got got lost sad ran book...
# 4       rather slow episod build upcom war episod left...
# 7       filler episod far stori goe thing signific plo...
# 8       honour attend first episod last season belfast...
# 11      episod time felt rush instanc dani find one dr...
# 13      game throne go drain admit peopl wei benioff t...
# 14      thought season major step season show shift un...
# 15      ive wait nearli year middl episod felt like im...
# 16      lazi write cheesi joke unemot reunion round pr...
# 17      ok guy realli dont understand expect caus see ...
# 18      ah charact havent seen sinc plot point multipl...
# 19      moment jon ride dragon first time epic comic d...
# 21      show coupl season miss spark someth episod dis...
# 22      averag act like parent think child never anyth...
# 24      cant beliv writter manag screw thing bad dont ...
# ...

# %%
reviews.to_csv('got_reviews', encoding='utf-8')

# %%
deef = pd.read_csv('got_reviews', header=None, index_col=[0])
deef.head()
# Out:
#                                                    1
# 0
# 0  open credit chang credit nice radic chang icon...
# 2  bad becom blank made got got lost sad ran book...
# 4  rather slow episod build upcom war episod left...
# 7  filler episod far stori goe thing signific plo...
# 8  honour attend first episod last season belfast...

# %%
sentiments.to_csv('got_sentiments', encoding='utf-8')

# %%
deef1 = pd.read_csv('got_sentiments', header=None, index_col=[0])
deef1.head()
# Out:
#    1
# 0
# 0  1
# 2  1
# 4  1
# 7  0
# 8  1

# %%
import pickle
pickle.dump(cv.vocabulary_,open("got_cv_reviews.pkl","wb"))
pickle.dump(tv.vocabulary_,open("got_tfidf_reviews.pkl","wb"))
